# %%
import pandas as pd
my_running = pd.read_csv(r"C:\Users\krist\PSY-3035\github\ExamPSY3035\Data\runlog\my_running.csv")

# %%
my_running
# Out:
#     Activity ID              Activity Date  \
# 0   11288364028   Apr 29, 2024, 5:14:04 AM
# 1   11327182053    May 4, 2024, 6:54:55 AM
# 2   11354165092    May 7, 2024, 4:31:09 PM
# 3   11371024533    May 9, 2024, 4:22:16 PM
# 4   11402044804   May 13, 2024, 2:30:00 PM
# 5   11425811688   May 16, 2024, 4:58:18 PM
# 6   11447612172  May 19, 2024, 12:34:48 PM
# 7   11463824675   May 21, 2024, 2:31:21 PM
# 8   11478659771  May 23, 2024, 12:47:45 PM
# 9   11491349434   May 25, 2024, 8:00:08 AM
# 10  11504674828   May 26, 2024, 6:26:35 PM
# 11  11518449873   May 28, 2024, 4:55:00 PM
# 12  11535082647   May 30, 2024, 6:26:47 PM
# 13  11539555466  May 31, 2024, 11:27:34 AM
# 14  11563861067    Jun 3, 2024, 2:55:18 PM
# 15  11597675325    Jun 7, 2024, 5:41:10 PM
# 16  11612344724    Jun 9, 2024, 1:28:23 PM
# 17  11656959150  Jun 15, 2024, 10:28:28 AM
# 18  11674087087   Jun 17, 2024, 2:08:23 PM
# 19  11719328361  Jun 23, 2024, 11:14:45 AM
# 20  11736909938   Jun 25, 2024, 3:10:45 PM
# ...

# %%
my_running.describe
# Out:
# <bound method NDFrame.describe of     Activity ID              Activity Date  \
# 0   11288364028   Apr 29, 2024, 5:14:04 AM
# 1   11327182053    May 4, 2024, 6:54:55 AM
# 2   11354165092    May 7, 2024, 4:31:09 PM
# 3   11371024533    May 9, 2024, 4:22:16 PM
# 4   11402044804   May 13, 2024, 2:30:00 PM
# 5   11425811688   May 16, 2024, 4:58:18 PM
# 6   11447612172  May 19, 2024, 12:34:48 PM
# 7   11463824675   May 21, 2024, 2:31:21 PM
# 8   11478659771  May 23, 2024, 12:47:45 PM
# 9   11491349434   May 25, 2024, 8:00:08 AM
# 10  11504674828   May 26, 2024, 6:26:35 PM
# 11  11518449873   May 28, 2024, 4:55:00 PM
# 12  11535082647   May 30, 2024, 6:26:47 PM
# 13  11539555466  May 31, 2024, 11:27:34 AM
# 14  11563861067    Jun 3, 2024, 2:55:18 PM
# 15  11597675325    Jun 7, 2024, 5:41:10 PM
# 16  11612344724    Jun 9, 2024, 1:28:23 PM
# 17  11656959150  Jun 15, 2024, 10:28:28 AM
# 18  11674087087   Jun 17, 2024, 2:08:23 PM
# 19  11719328361  Jun 23, 2024, 11:14:45 AM
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset (update the path to match your file location)
df = pd.read_csv(r"C:\Users\krist\PSY-3035\github\ExamPSY3035\Data\runlog\my_running.csv")

# Convert activity_date to datetime format
df['Activity Date'] = pd.to_datetime(df['Activity Date'])
df["hour"] = df['Activity Date'].dt.hour  # Extract hour

# %%
print(df.columns)  # Check column names
# Out:
# Index(['Activity ID', 'Activity Date', 'Activity Name', 'Activity Type',
#        'Activity Description', 'Elapsed Time', 'Distance', 'Max Heart Rate',
#        'Relative Effort', 'Commute', 'Activity Private Note', 'Activity Gear',
#        'Filename', 'Athlete Weight', 'Bike Weight', 'Elapsed Time.1',
#        'Moving Time', 'Distance.1', 'Max Speed', 'Average Speed',
#        'Elevation Gain', 'Elevation Loss', 'Elevation Low', 'Elevation High',
#        'Max Grade', 'Average Grade', 'Average Positive Grade',
#        'Average Negative Grade', 'Max Cadence', 'Average Cadence',
#        'Max Heart Rate.1', 'Average Heart Rate', 'Max Watts', 'Average Watts',
#        'Calories', 'Max Temperature', 'Average Temperature',
#        'Relative Effort.1', 'Total Work', 'Number of Runs', 'Uphill Time',
#        'Downhill Time', 'Other Time', 'Perceived Exertion', 'Type',
#        'Start Time', 'Weighted Average Power', 'Power Count',
# ...

# %%
def classify_time(hour):
    if hour < 12:
        return "Morning"
    elif hour >= 17:
        return "Evening"
    else:
        return "Afternoon"

df["time_of_day"] = df["hour"].apply(classify_time)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df["time_of_day"], y=df['Average Grade Adjusted Pace'])
plt.xlabel("Time of Day")
plt.ylabel('Average Grade Adjusted Pace')
plt.title("Running Pace: Morning vs. Evening")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.violinplot(x=df["time_of_day"], y=df['Average Grade Adjusted Pace'])
plt.xlabel("Time of Day")
plt.ylabel('Average Grade Adjusted Pace')
plt.title("Pace Distribution: Morning vs. Evening")
plt.grid()
plt.show()

# %%
morning_pace = df[df["time_of_day"] == "Morning"]["Average Grade Adjusted Pace"]
evening_pace = df[df["time_of_day"] == "Evening"]["Average Grade Adjusted Pace"]

t_stat, p_value = stats.ttest_ind(morning_pace, evening_pace, nan_policy="omit")
print(f"T-statistic: {t_stat}, P-value: {p_value}")

if p_value < 0.05:
    print("Statistically significant: Your pace is different in the evening!")
else:
    print("No significant difference in pace between morning and evening runs.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 4
#       1 morning_pace = df[df["time_of_day"] == "Morning"]["Average Grade Adjusted Pace"]
#       2 evening_pace = df[df["time_of_day"] == "Evening"]["Average Grade Adjusted Pace"]
# ----> 4 t_stat, p_value = stats.ttest_ind(morning_pace, evening_pace, nan_policy="omit")
#       5 print(f"T-statistic: {t_stat}, P-value: {p_value}")
#       7 if p_value < 0.05:
#
# NameError: name 'stats' is not defined

# %%
from scipy import stats

# %%
morning_pace = df[df["time_of_day"] == "Morning"]["Average Grade Adjusted Pace"]
evening_pace = df[df["time_of_day"] == "Evening"]["Average Grade Adjusted Pace"]

t_stat, p_value = stats.ttest_ind(morning_pace, evening_pace, nan_policy="omit")
print(f"T-statistic: {t_stat}, P-value: {p_value}")

if p_value < 0.05:
    print("Statistically significant: Your pace is different in the evening!")
else:
    print("No significant difference in pace between morning and evening runs.")
# Out:
# T-statistic: 0.30688949464691606, P-value: 0.761688752327685
# No significant difference in pace between morning and evening runs.

# %%
df_5k = df[df["Distance"] == 5]  # Keep only 5 km runs

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df_5k["time_of_day"], y=df_5k["Average Grade Adjusted Pace"])
plt.xlabel("Time of Day")
plt.ylabel("Average Grade Adjusted Pace (min/km)")
plt.title("Running Pace for 5K: Morning vs. Evening")
plt.grid()
plt.show()

# %%
df_4_6k = df[(df["Distance"] >= 4) & (df["Distance"] <= 6)]  # Keep runs between 4 and 6 km

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df_4_6k["time_of_day"], y=df_4_6k["Average Grade Adjusted Pace"])
plt.xlabel("Time of Day")
plt.ylabel("Average Grade Adjusted Pace (min/km)")
plt.title("Running Pace for 4-6K: Morning vs. Evening")
plt.grid()
plt.show()

# %%
df_4_6k_filtered = df_4_6k[df_4_6k["time_of_day"] != "Afternoon"]

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df_4_6k_filtered["time_of_day"], y=df_4_6k_filtered["Average Grade Adjusted Pace"])
plt.xlabel("Time of Day")
plt.ylabel("Average Grade Adjusted Pace (min/km)")
plt.title("Running Pace for 4-6K: Morning vs. Evening (Afternoon Removed)")
plt.grid()
plt.show()
plt.color =['peachpuff', 'tomato']

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[141], line 2
#       1 plt.figure(figsize=(6, 4))
# ----> 2 sns.boxplot(data=data, palette="coolwarm")  # Try "Blues", "viridis", "magma", etc.
#       3 plt.title("Boxplot with Seaborn Palette")
#       4 plt.show()
#
# NameError: name 'data' is not defined
